# %% [markdown]
# # Step 3: RAG Query Pipeline with Llama
#
# This notebook brings everything together:
# 1. **Retrieve** - Search ChromaDB for relevant services
# 2. **Augment** - Add those services as context
# 3. **Generate** - Use Llama to create helpful responses
#
# **Make sure Ollama is running:** Open a terminal and run `ollama serve`

# %% [markdown]
# ## Install Required Package

# %%
# Only need to run once, will install quietly 
# !pip install ollama -q

# %% [markdown]
# ## Load Our Existing Components

# %%
import json
import chromadb
from sentence_transformers import SentenceTransformer
import ollama
import warnings
warnings.filterwarnings("ignore")

# Load embedding model (same one from notebook 02)
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
print("Embedding model loaded!")

# Connect to ChromaDB (created in notebook 02)
chroma_client = chromadb.PersistentClient(path="../data/chroma_db")
collection = chroma_client.get_collection("services")
print(f"Connected to ChromaDB with {collection.count()} services")

# Load full service data (for detailed responses)
with open('../data/homeless_services_hackathon.json', 'r') as f:
    all_services = json.load(f)
print(f"Loaded {len(all_services)} full service records")
# Out:
# Embedding model loaded!
# Connected to ChromaDB with 1719 services
# Loaded 1719 full service records

# %% [markdown]
# ## Test Ollama Connection

# %%
# Test that Ollama is running
try:
    response = ollama.chat(model='llama3.2', messages=[
        {'role': 'user', 'content': 'Say "Hello, I am ready!" and nothing else.'}
    ])
    print("Ollama connection successful!")
    print(f"Response: {response['message']['content']}")
except Exception as e:
    print(f"Error: {e}")
    print("Make sure Ollama is running: open a terminal and run 'ollama serve'")
# Out:
# Ollama connection successful!
# Response: Hello, I am ready!

# %% [markdown]
# ## Build the RAG Pipeline

# %%
def search_services(query, n_results=5):
    """
    Search for services matching the query using semantic similarity.
    """
    query_embedding = embedding_model.encode(query).tolist()
    
    results = collection.query(
        query_embeddings=[query_embedding],
        n_results=n_results
    )
    
    return results


def format_services_for_llm(search_results):
    """
    Format search results into a clear context string for the LLM.
    """
    services_text = ""
    
    for i, (meta, doc) in enumerate(zip(search_results['metadatas'][0], search_results['documents'][0])):
        services_text += f"""
---
SERVICE {i+1}: {meta.get('service_name', 'Unknown')}
Organization: {meta.get('organization', 'N/A')}
Phone: {meta.get('phone', 'N/A')}
Address: {meta.get('address', 'N/A')}
Types: {meta.get('types', 'N/A')}
Area Served: {meta.get('area_served', 'N/A')}

Full Details:
{doc[:1500]}
"""
    
    return services_text


def ask_case_manager_assistant(user_query, n_services=5):
    """
    Main RAG function: Search for services and generate a helpful response.
    """
    # Step 1: RETRIEVE - Search for relevant services
    search_results = search_services(user_query, n_results=n_services)
    
    # Step 2: AUGMENT - Format services as context
    services_context = format_services_for_llm(search_results)
    
    # Step 3: GENERATE - Create the prompt and get LLM response
    system_prompt = """You are a helpful assistant for case managers working with homeless and at-risk populations in San Diego.

Your job is to:
1. Analyze the services provided in the context
2. Recommend the most relevant services for the client's situation
3. Explain eligibility requirements clearly
4. Provide contact information and next steps
5. Note any important details (hours, documents needed, etc.)

Be concise but thorough. If a service doesn't seem like a good match, say so.
Always prioritize the client's immediate needs."""

    user_message = f"""A case manager is asking: "{user_query}"

Here are the relevant services from our database:
{services_context}

Based on these services, provide helpful recommendations for the case manager."""

    # Call Llama via Ollama
    response = ollama.chat(
        model='llama3.2',
        messages=[
            {'role': 'system', 'content': system_prompt},
            {'role': 'user', 'content': user_message}
        ]
    )
    
    return {
        'answer': response['message']['content'],
        'services_found': [m['service_name'] for m in search_results['metadatas'][0]]
    }

print("RAG pipeline ready!")
# Out:
# RAG pipeline ready!

# %% [markdown]
# ## Test the RAG Pipeline

# %%
# Test query 1: Veteran shelter
query = "I have a homeless veteran who needs emergency shelter tonight"

print(f"QUERY: {query}")
print("=" * 70)

result = ask_case_manager_assistant(query)

print("\nSERVICES FOUND:")
for svc in result['services_found']:
    print(f"  - {svc}")

print("\n" + "=" * 70)
print("ASSISTANT RESPONSE:")
print("=" * 70)
print(result['answer'])
# Out:
# QUERY: I have a homeless veteran who needs emergency shelter tonight
# ======================================================================
#
# SERVICES FOUND:
#   - National Call Center for Homeless Veterans
#   - Harm Reduction Shelter
#   - Emergency Adult Shelter VVSD
#   - Emergency Adult Shelter VVSD
#   - Homeless Veterans' Reintegration Program
#
# ======================================================================
# ASSISTANT RESPONSE:
# ======================================================================
# **Recommendation for Emergency Shelter for a Homeless Veteran**
#
# Considering the client is a homeless veteran in need of emergency shelter, I recommend contacting the National Call Center for Homeless Veterans (SERVICE 1) first to assess their situation and provide guidance on available resources.
#
# The National Call Center can help determine the level of care required and connect the veteran with local services. However, since they do not have a physical location, it's unlikely that they would be able to provide immediate shelter.
#
# Next, I recommend reaching out to Father Joe's Villages (SERVICE 3) for Emergency Adult Shelter VVSD, as they offer a 24-hour emergency shelter specifically designed for homeless men. Although the service is limited to male participants, there might be an exception if the case manager can demonstrate that this service would still meet the client's needs.
#
# Given the client's status as a veteran, it may also be beneficial to contact the Homeless Veterans' Reintegration Program (SERVICE 5) to explore their services. This program provides housing referrals, vocational assessments, job readiness training, and other supportive services tailored to veterans experiencing or at risk of homelessness.
#
# **Eligibility Requirements:**
#
# * SERVICE 1: Eligible veterans can call the National Call Center for Homeless Veterans.
# * SERVICE 3: Male participants are required; however, case management may assist with exceptions if necessary.
# * SERVICE 5: Eligible veterans must have a discharge status of "Other Than Honorable" or higher.
#
# **Contact Information and Next Steps:**
#
# * National Call Center for Homeless Veterans (SERVICE 1): (877) 424-3838
# * Father Joe's Villages (SERVICE 3): (619) 233-8500
# * Homeless Veterans' Reintegration Program (SERVICE 5): (619) 266-4247
#
# Please note that it's essential to verify eligibility requirements and availability of services for each option before proceeding.
#
# **Important Details:**
#
# * Service hours and availability may vary.
# * Some services might require an initial phone screening or in-person meeting.
# * Case management will need to work closely with the client to ensure their needs are met.

# %%
# Test query 2: Family with children
query = "Single mother with 2 kids facing eviction, needs rent assistance and possibly shelter"

print(f"QUERY: {query}")
print("=" * 70)

result = ask_case_manager_assistant(query)

print("\nSERVICES FOUND:")
for svc in result['services_found']:
    print(f"  - {svc}")

print("\n" + "=" * 70)
print("ASSISTANT RESPONSE:")
print("=" * 70)
print(result['answer'])
# Out:
# QUERY: Single mother with 2 kids facing eviction, needs rent assistance and possibly shelter
# ======================================================================
#
# SERVICES FOUND:
#   - Long Term Transitional Housing
#   - Rent and Utility Payment Assistance
#   - City of San Diego Eviction Prevention Program
#   - Emergency Family Shelter
#   - Transitional Housing for Families, St Vincent de Paul Village
#
# ======================================================================
# ASSISTANT RESPONSE:
# ======================================================================
# **Recommendations:**
#
# 1. **City of San Diego Eviction Prevention Program**: Given the client's immediate need to avoid eviction, this program is a high priority. The client can reach out to (877) 534-2524 to inquire about eligibility and the application process.
# 2. **Emergency Family Shelter (Interfaith Community Services)**: As an alternative or supplement to Long Term Transitional Housing, this shelter can provide temporary stability while the family navigates their housing situation. Eligibility guidelines must be carefully reviewed.
# 3. **Rent and Utility Payment Assistance (Brother Benno Foundation)**: If the client receives a 3-day Notice to Pay Rent or Quit, assistance with rent and utilities may be available. The organization serves areas outside of San Diego City limits.
#
# **Not recommended at this time:**
#
# 1. Long Term Transitional Housing (Solutions for Change) - while this service is designed for families, it has a specific eligibility requirement that the client may not meet due to being "homeless" according to HUD guidelines and willing to work full-time.
# 2. Transitional Housing for Families (Father Joe's Villages) - as it provides long-term housing, it may not be the best fit for someone facing eviction.
#
# **Eligibility requirements:**
#
# * City of San Diego Eviction Prevention Program: Household income at or below 80% AMI ($121,250/year for a family of four); reside at a City of San Diego address; have an obligation to pay rent.
# * Emergency Family Shelter (Interfaith Community Services): Families must be homeless or at risk of homelessness and meet HUD requirements. A background check is also required.
#
# **Important details:**
#
# * Phone numbers and addresses are provided for each organization. The case manager should verify that the information is up-to-date.
# * Proof of income, rent paid, and housing obligations may be requested by some organizations as part of the application process.
# * Background checks may be required for Emergency Family Shelter services.
#
# **Next steps:**
#
# 1. Contact City of San Diego Eviction Prevention Program to inquire about eligibility and the application process.
# 2. Reach out to Emergency Family Shelter (Interfaith Community Services) to discuss their intake process and ensure the client meets their eligibility guidelines.
# 3. Encourage the client to contact Brother Benno Foundation for assistance with rent and utilities if they receive a 3-day Notice to Pay Rent or Quit.
#
# **Case management notes:**
#
# * Monitor the situation closely, as eviction can have severe consequences on the family's well-being.
# * Ensure that all necessary documents are collected and submitted to each organization in a timely manner.
# * Schedule follow-up appointments with the client to review their progress and adjust services as needed.

# %%
# Test query 3: Mental health
query = "Young adult age 20 experiencing mental health crisis, needs counseling and possibly housing"

print(f"QUERY: {query}")
print("=" * 70)

result = ask_case_manager_assistant(query)

print("\nSERVICES FOUND:")
for svc in result['services_found']:
    print(f"  - {svc}")

print("\n" + "=" * 70)
print("ASSISTANT RESPONSE:")
print("=" * 70)
print(result['answer'])
# Out:
# QUERY: Young adult age 20 experiencing mental health crisis, needs counseling and possibly housing
# ======================================================================
#
# SERVICES FOUND:
#   - Adult Short-Term Residential Treatment, Jary Barreto Crisis Center
#   - Adult Short-Term Residential Treatment, New Vistas Crisis Center
#   - Adult Short-Term Residential Treatment, Turning Point Crisis Center
#   - Adult Short-Term Residential Treatment, Halcyon Crisis Center
#   - North Inland Mental Health Center
#
# ======================================================================
# ASSISTANT RESPONSE:
# ======================================================================
# **Recommendations for the 20-year-old young adult experiencing a mental health crisis**
#
# Considering the client's primary issue is a mental health crisis, all four Adult Short-Term Residential Treatment services (Jary Barreto Crisis Center, New Vistas Crisis Center, Turning Point Crisis Center, and Halcyon Crisis Center) from Community Research Foundation seem like potential options. However, I would recommend **Jary Barreto Crisis Center** as the primary service to consider.
#
# Here's why:
#
# * All four services have similar descriptions and eligibility requirements.
# * Jary Barreto Crisis Center has the most current phone number among the listed services (619-232-4357).
# * This service provides a 24-hour crisis residence, which aligns with the client's immediate needs.
#
# The other three services from Community Research Foundation have additional areas of focus that may be less relevant for this specific situation. Additionally, North Inland Mental Health Center seems to cater more towards individuals with chronic mental illness and has different eligibility requirements (18 years and older with severe mental illness).
#
# **Important Notes:**
#
# * Each service requires a primary crisis related to a mental health issue.
# * Substance dependence crisis and/or homelessness may not be the primary focus of these services.
#
# **Next Steps:**
#
# 1. Contact Jary Barreto Crisis Center at (619) 232-4357 to inquire about availability and admissions process.
# 2. Confirm eligibility requirements and provide necessary documents (e.g., identification, insurance information).
# 3. Explore potential next steps for housing support and counseling after discharge from the residential treatment program.
#
# **Contact Information:**
#
# * Community Research Foundation: (619) 232-4357
# * Jary Barreto Crisis Center: (619) 232-4357
#
# Please note that these services may have different availability, waitlists, or requirements. It's essential to confirm details with each service before proceeding.

# %% [markdown]
# ## Interactive Query Mode
#
# Run this cell to ask your own questions:

# %%
# Interactive mode - change this query and run the cell
your_query = "elderly person needs help with food and utilities"

print(f"QUERY: {your_query}")
print("=" * 70)

result = ask_case_manager_assistant(your_query)

print("\nSERVICES FOUND:")
for svc in result['services_found']:
    print(f"  - {svc}")

print("\n" + "=" * 70)
print("ASSISTANT RESPONSE:")
print("=" * 70)
print(result['answer'])
# Out:
# QUERY: elderly person needs help with food and utilities
# ======================================================================
#
# SERVICES FOUND:
#   - Senior Nutrition Program
#   - Senior Services
#   - Senior Food Program, Church at Rancho Bernardo
#   - Rent and Utility Payment Assistance
#   - Senior Food Program, Mira Mesa Senior Center
#
# ======================================================================
# ASSISTANT RESPONSE:
# ======================================================================
# Recommendation:
#
# Based on the client's need for food and utilities assistance, I recommend that the case manager consider the following services:
#
# 1. **Senior Nutrition Program (City of National City)**:
# 	* Provides congregate lunches, home-delivered meals, and free transportation to/from the center.
# 	* Eligible: All National City residents aged 60+, meets the program's income guidelines.
# 	* This service seems like a great match for the client's immediate needs.
# 2. **Senior Food Program (Mira Mesa Senior Center)**:
# 	* Offers monthly food distributions, nutrition education, and meets the same eligibility criteria as the other senior food programs.
# 	* Eligible: Low-income seniors aged 60+, resides in San Diego County, and meets the income guidelines.
# 	* This service could be a good supplement to the client's existing needs.
#
# I do not recommend **Senior Food Program (Church at Rancho Bernardo)** due to its limited geographic area (Rancho Bernado) and no direct transportation options.
#
# For utilities assistance, I suggest:
#
# 1. **Rent and Utility Payment Assistance (Brother Benno Foundation)**:
# 	* Offers emergency rent and utility payment assistance for seniors, families with small children, or individuals with disabilities.
# 	* Eligible: Meets specific income guidelines and residency requirements.
# 	* While this service may not be an exact match for utilities specifically, it could provide temporary financial relief.
#
# Important Notes:
#
# * All services require registration and/or proof of eligibility to participate.
# * Contact information should be provided to the case manager and client.
# * Documentation (e.g., ID, proof of income) might be needed for some services.
# * For transportation assistance, National City's Senior Nutrition Program seems like a good option.
#
# Next Steps:
#
# 1. Call (619) 336-6752 or visit the City of National City website to learn more about the Senior Nutrition Program.
# 2. Schedule an appointment with the Mira Mesa Senior Center to discuss their food program and eligibility requirements.
# 3. Reach out to Brother Benno Foundation at (760) 439-1244 to explore rent and utility payment assistance options.
#
# Please advise the client on these recommendations, services, and next steps, ensuring they understand the application process and any necessary documentation requirements.

# %% [markdown]
# ## Advanced: Compare Services Side-by-Side

# %%
def compare_services(query, client_profile):
    """
    Ask the LLM to compare services and recommend the best fit.
    """
    search_results = search_services(query, n_results=5)
    services_context = format_services_for_llm(search_results)
    
    prompt = f"""Compare these services for this client:

CLIENT PROFILE:
{client_profile}

AVAILABLE SERVICES:
{services_context}

Please:
1. Create a comparison table of the top 3 most relevant services
2. Recommend which service is the BEST fit and why
3. List any services that are NOT a good fit and why
4. Suggest a step-by-step action plan for the case manager"""

    response = ollama.chat(
        model='llama3.2',
        messages=[{'role': 'user', 'content': prompt}]
    )
    
    return response['message']['content']

# Example comparison
client = """
- 45 year old male
- Veteran (Army, 8 years)
- Currently sleeping in car
- Has part-time job at warehouse
- No mental health or substance issues
- Needs: stable housing, maybe help with deposit
"""

print("CLIENT PROFILE:")
print(client)
print("=" * 70)
print("\nCOMPARISON & RECOMMENDATIONS:")
print("=" * 70)
print(compare_services("veteran housing assistance", client))
# Out:
# CLIENT PROFILE:
#
# - 45 year old male
# - Veteran (Army, 8 years)
# - Currently sleeping in car
# - Has part-time job at warehouse
# - No mental health or substance issues
# - Needs: stable housing, maybe help with deposit
#
# ======================================================================
#
# COMPARISON & RECOMMENDATIONS:
# ======================================================================
# **Comparison Table: Top 3 Most Relevant Services**
#
# | Service | Service Type | Eligibility | Target Population |
# | --- | --- | --- | --- |
# | Veteran's Association of Real Estate Professionals (USA Homeownership Foundation, Inc.) | Housing Financial Assistance, Veteran Services | Active duty service members, veterans, reservists, National Guard members, surviving spouses, and military families | Active Military/Veterans |
# | Coordinated Entry Access Site (CES), VA Healthcare Systems, Oceanside | Homelessness Prevention & Diversion | Veterans who are homeless or at risk of homelessness | Homeless Veterans/At Risk for Homelessness |
# | Adjoin Veterans SSVF Rapid Re-Housing, San Diego | Homelessness Prevention & Diversion | Limited to individuals where the head of household is a military Veteran with a discharge status other than dishonorable | Low Income/Service Members with Other Than Dishonorable Discharge/Homeless Veterans |
#
# **Recommendation:**
#
# Based on the client's profile and needs, I recommend **Adjoin Veterans SSVF Rapid Re-Housing, San Diego** as the BEST fit service. This program provides temporary financial assistance, short-term rental support, case management, housing search assistance, and service referrals for Veterans and their families experiencing or at risk of homelessness.
#
# The client's part-time job at a warehouse, stable income, and lack of mental health or substance issues make this program more suitable compared to the other services. While the Veteran's Association of Real Estate Professionals can provide financial literacy education and homebuyer assistance, it may not be as effective in providing immediate support for housing stability.
#
# **Not a Good Fit:**
#
# 1. **National Call Center for Homeless Veterans**: This service is focused on mental health services and general veteran services, which do not address the client's specific need for stable housing.
# 2. **VI-SPDAT Assessment Site, VA Medical Center, Homeless Outreach Clinic**: While this assessment site provides a vulnerability index to determine the most appropriate housing intervention, it may not be directly applicable to clients who have already secured employment and are in need of housing support.
#
# **Step-by-Step Action Plan for Case Manager:**
#
# 1. **Contact Adjoin Veterans SSVF Rapid Re-Housing, San Diego**: Reach out to the program staff to discuss the client's needs and eligibility for the program.
# 2. **Assess Client Eligibility**: Review the client's financial situation, employment history, and housing status to determine their eligibility for the program.
# 3. **Gather Required Documents**: Collect necessary documents from the client, such as income verification, proof of employment, and identification.
# 4. **Complete Application**: Submit the client's application through Adjoin's online portal or in-person at a designated location.
# 5. **Coordinate with Program Staff**: Work with Adjoin staff to schedule an intake appointment and begin the case management process.
# 6. **Monitor Progress**: Regularly follow up with the client to monitor their progress, provide support, and address any challenges that arise during the program.
# 7. **Transition to Permanent Housing**: When the client has secured stable housing through the program, ensure they have access to ongoing support services, such as employment assistance and health care referrals.
#
# By following this action plan, the case manager can effectively connect the client with the Adjoin Veterans SSVF Rapid Re-Housing, San Diego program and provide them with the necessary support to achieve stable housing.

# %% [markdown]
# ## Summary
#
# We now have a working RAG pipeline that:
#
# 1. **Searches** our services database semantically
# 2. **Generates** helpful, contextual responses using Llama
# 3. **Compares** services for specific client profiles
#
# ### Project Progress
#
# | Component | Purpose | Status |
# |-----------|---------|--------|
# | Classification | Multi-label service type tagging (22 types) | Notebook 04 |
# | Enhanced RAG | Classification-aware retrieval + re-ranking | Notebook 05 |
# | Information Extraction | Structure messy fields (eligibility, hours) | Future |
# | Client-Specific Ranking | Score services for specific client profiles | Future |
# | Web Interface | Let case managers use this easily | Future |
