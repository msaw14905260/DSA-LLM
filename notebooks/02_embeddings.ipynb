# %% [markdown]
# # Step 2: Create Embeddings for Semantic Search
#
# **What are embeddings?**
# - Embeddings convert text into numbers (vectors) that capture meaning
# - Similar meanings = similar vectors
# - This lets us search by *meaning*, not just keywords
#
# **Example:**
# - Query: "help for homeless veteran"
# - Finds: "Transitional Housing for Veterans" (even though words don't match exactly)

# %% [markdown]
# ## Install Required Packages
#
# Run this once to install what we need:

# %%
# Run this cell once to install packages
# !pip install sentence-transformers chromadb
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.2.2-py3-none-any.whl.metadata (16 kB)
# Collecting chromadb
#   Downloading chromadb-1.4.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (7.2 kB)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from sentence-transformers) (4.54.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from sentence-transformers) (0.34.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from sentence-transformers) (2.7.1)
# Requirement already satisfied: numpy in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from sentence-transformers) (2.2.4)
# Requirement already satisfied: scikit-learn in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from sentence-transformers) (1.16.2)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from sentence-transformers) (4.12.2)
# Requirement already satisfied: tqdm in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: filelock in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: packaging>=20.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: requests in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.5)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.4.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pydantic>=1.9 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from chromadb) (2.11.1)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.7 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.0)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb)
#   Downloading posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.23.2-cp312-cp312-macosx_13_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from chromadb) (1.31.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading pypika-0.50.0-py2.py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: overrides>=7.3.1 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from chromadb) (7.7.0)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from chromadb) (0.15.1)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-35.0.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from chromadb) (9.0.0)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from chromadb) (3.10.16)
# Requirement already satisfied: httpx>=0.27.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: six>=1.5 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Collecting distro>=1.5.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.1.31)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: anyio in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.22.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: coloredlogs in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (14.0)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: protobuf in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: sympy in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.11.0)
# Requirement already satisfied: zipp>=0.5 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb) (1.17.2)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.69.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.31.1 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-proto==1.31.1 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.52b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (0.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: setuptools in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (75.8.0)
# Requirement already satisfied: networkx in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (14.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=7.1 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: joblib>=1.2.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Downloading sentence_transformers-5.2.2-py3-none-any.whl (494 kB)
# Downloading chromadb-1.4.1-cp39-abi3-macosx_11_0_arm64.whl (19.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.6/19.6 MB 1.6 MB/s  0:00:12 eta 0:00:01m
# Downloading posthog-5.4.0-py3-none-any.whl (105 kB)
# Downloading build-1.4.0-py3-none-any.whl (24 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading kubernetes-35.0.0-py2.py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 4.5 MB/s  0:00:00 eta 0:00:01
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading mmh3-5.2.0-cp312-cp312-macosx_11_0_arm64.whl (40 kB)
# Downloading onnxruntime-1.23.2-cp312-cp312-macosx_13_0_arm64.whl (17.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 5.0 MB/s  0:00:03 eta 0:00:01
# Downloading pybase64-1.4.3-cp312-cp312-macosx_11_0_arm64.whl (31 kB)
# Downloading pypika-0.50.0-py2.py3-none-any.whl (60 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: pypika, flatbuffers, durationpy, pyproject_hooks, pybase64, oauthlib, mmh3, importlib-resources, distro, requests-oauthlib, posthog, onnxruntime, build, kubernetes, sentence-transformers, chromadb
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [chromadb]/16 [chromadb]transformers]
# Successfully installed build-1.4.0 chromadb-1.4.1 distro-1.9.0 durationpy-0.10 flatbuffers-25.12.19 importlib-resources-6.5.2 kubernetes-35.0.0 mmh3-5.2.0 oauthlib-3.3.1 onnxruntime-1.23.2 posthog-5.4.0 pybase64-1.4.3 pypika-0.50.0 pyproject_hooks-1.2.0 requests-oauthlib-2.0.0 sentence-transformers-5.2.2

# %% [markdown]
# ## Load the Data

# %%
import json

with open('../data/homeless_services_hackathon.json', 'r') as f:
    services = json.load(f)

print(f"Loaded {len(services)} services")
# Out:
# Loaded 1719 services

# %% [markdown]
# ## Prepare Text for Embeddings
#
# We need to combine the important fields into a single text string for each service.
# This is what the embedding model will "read" to understand each service.

# %%
def create_service_text(service):
    """
    Combine relevant fields into a single searchable text.
    This is what gets converted to an embedding.
    """
    parts = []
    
    # Core info
    if service.get('service_name'):
        parts.append(f"Service: {service['service_name']}")
    if service.get('organization'):
        parts.append(f"Organization: {service['organization']}")
    if service.get('description'):
        parts.append(f"Description: {service['description']}")
    
    # Who it's for
    if service.get('eligibility'):
        parts.append(f"Eligibility: {service['eligibility']}")
    if service.get('target_populations'):
        parts.append(f"Target Population: {service['target_populations']}")
    
    # What type of service
    if service.get('types'):
        parts.append(f"Service Types: {', '.join(service['types'])}")
    if service.get('areas_of_focus'):
        parts.append(f"Areas of Focus: {', '.join(service['areas_of_focus'])}")
    
    # Location
    if service.get('area_served'):
        parts.append(f"Area Served: {service['area_served']}")
    
    return "\n".join(parts)

# Test it on one service
sample_text = create_service_text(services[0])
print("Sample service text:")
print("-" * 50)
print(sample_text[:1000])  # First 1000 chars
# Out:
# Sample service text:
# --------------------------------------------------
# Service: Interim Shelter Bed Program (ISB)
# Organization: Urban Street Angels
# Description: Offers an interim shelter program that provides shelter for homeless youth who need a bed and food in a trauma-informed environment.
#
# Offers the following once enlisted:
# •	Food
# •	Hygiene supplies
# •	Clothing
# •	Transitional housing
# •	Job search assistance
# •	Education opportunities
# •	Case management
# •	Mental health therapy
# •	Substance abuse treatment
# •	Transportation support
# Eligibility: Must be 18-24 years old, currently homeless, living at a temporary shelter or institution, or at risk of experiencing homelessness
# Target Population: Homeless Youth/Runaway/Youth Shelter Residents/
# Service Types: Case Management & Coordination, TAY Services, Mental Health Services, Transitional & Supportive Housing, Emergency Shelter & Crisis Intervention, Homelessness Prevention & Diversion, Food & Basic Needs Assistance, Substance Abuse Disorder
# Areas of Focus: Youth Shelters, Personal, Grooming Supplies, Ongoin

# %% [markdown]
# ## Create the Embedding Model
#
# We're using `sentence-transformers` - it's free and runs locally (no API key needed).

# %%
from sentence_transformers import SentenceTransformer

# This model is good for semantic search
# First run will download the model (~90MB)
model = SentenceTransformer('all-MiniLM-L6-v2')

print("Model loaded!")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Model loaded!

# %% [markdown]
# ## Set Up ChromaDB (Vector Database)
#
# ChromaDB stores our embeddings and lets us search them quickly.

# %%
import chromadb

# Create a persistent database (saves to disk)
chroma_client = chromadb.PersistentClient(path="../data/chroma_db")

# Delete existing collection if it exists (for clean reruns)
try:
    chroma_client.delete_collection("services")
except:
    pass

# Create a new collection
collection = chroma_client.create_collection(
    name="services",
    metadata={"description": "Homeless services from 211 San Diego"}
)

print("ChromaDB collection created!")
# Out:
# ChromaDB collection created!

# %% [markdown]
# ## Generate Embeddings and Store in Database
#
# This will take a minute or two to process all services.

# %%
from tqdm import tqdm  # Progress bar

# Process in batches for efficiency
batch_size = 100

for i in tqdm(range(0, len(services), batch_size), desc="Processing services"):
    batch = services[i:i + batch_size]
    
    # Create text for each service
    texts = [create_service_text(s) for s in batch]
    
    # Generate embeddings
    embeddings = model.encode(texts).tolist()
    
    # Create IDs and metadata
    ids = [str(i + j) for j in range(len(batch))]
    
    # Store metadata we'll want when retrieving results
    metadatas = [{
        "service_name": s.get('service_name', ''),
        "organization": s.get('organization', ''),
        "phone": s.get('main_phone', ''),
        "address": s.get('address', ''),
        "url": s.get('url', ''),
        "types": ', '.join(s.get('types', [])),
        "area_served": s.get('area_served', '')
    } for s in batch]
    
    # Add to ChromaDB
    collection.add(
        embeddings=embeddings,
        documents=texts,
        metadatas=metadatas,
        ids=ids
    )

print(f"\nDone! Added {collection.count()} services to the database.")
# Out:
# Processing services:   0%|                               | 0/18 [00:00<?, ?it/s]/Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages/torch/nn/modules/module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Processing services: 100%|██████████████████████| 18/18 [00:06<00:00,  2.98it/s]
# Done! Added 1719 services to the database.

# %% [markdown]
# ## Test the Search!
#
# Let's try some queries a case manager might ask.

# %%
def search_services(query, n_results=5):
    """
    Search for services matching the query.
    Returns the top n_results matches.
    """
    # Convert query to embedding
    query_embedding = model.encode(query).tolist()
    
    # Search ChromaDB
    results = collection.query(
        query_embeddings=[query_embedding],
        n_results=n_results
    )
    
    return results

# Test query
query = "I need shelter for a homeless veteran"
results = search_services(query)

print(f"Query: {query}")
print("=" * 60)
for i, (meta, doc) in enumerate(zip(results['metadatas'][0], results['documents'][0])):
    print(f"\n{i+1}. {meta['service_name']}")
    print(f"   Organization: {meta['organization']}")
    print(f"   Phone: {meta['phone']}")
    print(f"   Types: {meta['types'][:80]}...")
# Out:
# Query: I need shelter for a homeless veteran
# ============================================================
#
# 1. National Call Center for Homeless Veterans
#    Organization: United States Department of Veterans Affairs (VA)
#    Phone: (877) 424-3838
#    Types: Mental Health Services, Veteran Services...
#
# 2. Homeless Veterans' Reintegration Program
#    Organization: Able-Disabled Advocacy
#    Phone: (619) 266-4247
#    Types: Mental Health Services, Veteran Services...
#
# 3. Housing Stability Case Management
#    Organization: Interfaith Community Services
#    Phone: (760) 529-9979
#    Types: Disability Services, Case Management & Coordination, Housing Search & Navigation...
#
# 4. Coordinated Entry Access Site (CES), VA Healthcare Systems, Oceanside
#    Organization: United States Department of Veterans Affairs (VA)
#    Phone: (619) 497-8989
#    Types: Homelessness Prevention & Diversion, Disability Services, Case Management & Coor...
#
# 5. Harm Reduction Shelter
#    Organization: Alpha Project for the Homeless
#    Phone: (619) 860-2800
#    Types: Emergency Shelter & Crisis Intervention...

# %%
# Try more queries
test_queries = [
    "food assistance for seniors",
    "mental health services for youth",
    "help paying rent to avoid eviction",
    "domestic violence shelter",
    "job training for homeless adults"
]

for query in test_queries:
    results = search_services(query, n_results=3)
    print(f"\nQuery: {query}")
    print("-" * 40)
    for meta in results['metadatas'][0]:
        print(f"  - {meta['service_name']}")
# Out:
# Query: food assistance for seniors
# ----------------------------------------
#   - Senior Nutrition Program
#   - Senior Farmers Market Nutrition Program
#   - Senior Food Program, Back Country Support, Boulevard
#
# Query: mental health services for youth
# ----------------------------------------
#   - Adolescent Habilitative Learning Program
#   - Adolescent Intensive Outpatient - Healthy yoUth
#   - Children and Adolescent Mental Health Services
#
# Query: help paying rent to avoid eviction
# ----------------------------------------
#   - City of San Diego Eviction Prevention Program
#   - Rent and Utility Payment Assistance
#   - Housing and Foreclosure Counseling
#
# Query: domestic violence shelter
# ----------------------------------------
#   - National Domestic Violence Hotline
#   - Domestic Violence Shelters
#   - Domestic Violence Shelters
#
# Query: job training for homeless adults
# ----------------------------------------
#   - STEPS Program, San Diego Centre City Corps
#   - Long Term Transitional Housing
#   - Mission Academy, Holistic Transitional Housing Program

# %% [markdown]
# ## Summary
#
# We now have:
# 1. All services converted to embeddings
# 2. Stored in a searchable vector database
# 3. A `search_services()` function that finds relevant services by meaning
#
# **Next step (notebook 03):** Connect this to an LLM (Claude) to generate helpful, conversational responses instead of just returning raw results.
