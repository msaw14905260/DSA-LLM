# %% [markdown]
# # Step 3: RAG Query Pipeline with Llama
#
# This notebook brings everything together:
# 1. **Retrieve** - Search ChromaDB for relevant services
# 2. **Augment** - Add those services as context
# 3. **Generate** - Use Llama to create helpful responses
#
# **Make sure Ollama is running:** Open a terminal and run `ollama serve`

# %% [markdown]
# ## Install Required Package

# %%
# !pip install ollama
# Out:
# Requirement already satisfied: ollama in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (0.6.1)
# Requirement already satisfied: httpx>=0.27 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from ollama) (2.11.1)
# Requirement already satisfied: anyio in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from httpx>=0.27->ollama) (4.8.0)
# Requirement already satisfied: certifi in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from httpx>=0.27->ollama) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from httpx>=0.27->ollama) (3.10)
# Requirement already satisfied: h11>=0.16 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from pydantic>=2.9->ollama) (2.33.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from pydantic>=2.9->ollama) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from pydantic>=2.9->ollama) (0.4.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from anyio->httpx>=0.27->ollama) (1.3.1)

# %% [markdown]
# ## Load Our Existing Components

# %%
import json
import chromadb
from sentence_transformers import SentenceTransformer
import ollama

# Load embedding model (same one from notebook 02)
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
print("Embedding model loaded!")

# Connect to ChromaDB (created in notebook 02)
chroma_client = chromadb.PersistentClient(path="../data/chroma_db")
collection = chroma_client.get_collection("services")
print(f"Connected to ChromaDB with {collection.count()} services")

# Load full service data (for detailed responses)
with open('../data/homeless_services_hackathon.json', 'r') as f:
    all_services = json.load(f)
print(f"Loaded {len(all_services)} full service records")
# Out:
# Embedding model loaded!
# Connected to ChromaDB with 1719 services
# Loaded 1719 full service records

# %% [markdown]
# ## Test Ollama Connection

# %%
# Test that Ollama is running
try:
    response = ollama.chat(model='llama3.2', messages=[
        {'role': 'user', 'content': 'Say "Hello, I am ready!" and nothing else.'}
    ])
    print("Ollama connection successful!")
    print(f"Response: {response['message']['content']}")
except Exception as e:
    print(f"Error: {e}")
    print("Make sure Ollama is running: open a terminal and run 'ollama serve'")
# Out:
# Ollama connection successful!
# Response: Hello, I am ready!

# %% [markdown]
# ## Build the RAG Pipeline

# %%
def search_services(query, n_results=5):
    """
    Search for services matching the query using semantic similarity.
    """
    query_embedding = embedding_model.encode(query).tolist()
    
    results = collection.query(
        query_embeddings=[query_embedding],
        n_results=n_results
    )
    
    return results


def format_services_for_llm(search_results):
    """
    Format search results into a clear context string for the LLM.
    """
    services_text = ""
    
    for i, (meta, doc) in enumerate(zip(search_results['metadatas'][0], search_results['documents'][0])):
        services_text += f"""
---
SERVICE {i+1}: {meta.get('service_name', 'Unknown')}
Organization: {meta.get('organization', 'N/A')}
Phone: {meta.get('phone', 'N/A')}
Address: {meta.get('address', 'N/A')}
Types: {meta.get('types', 'N/A')}
Area Served: {meta.get('area_served', 'N/A')}

Full Details:
{doc[:1500]}
"""
    
    return services_text


def ask_case_manager_assistant(user_query, n_services=5):
    """
    Main RAG function: Search for services and generate a helpful response.
    """
    # Step 1: RETRIEVE - Search for relevant services
    search_results = search_services(user_query, n_results=n_services)
    
    # Step 2: AUGMENT - Format services as context
    services_context = format_services_for_llm(search_results)
    
    # Step 3: GENERATE - Create the prompt and get LLM response
    system_prompt = """You are a helpful assistant for case managers working with homeless and at-risk populations in San Diego.

Your job is to:
1. Analyze the services provided in the context
2. Recommend the most relevant services for the client's situation
3. Explain eligibility requirements clearly
4. Provide contact information and next steps
5. Note any important details (hours, documents needed, etc.)

Be concise but thorough. If a service doesn't seem like a good match, say so.
Always prioritize the client's immediate needs."""

    user_message = f"""A case manager is asking: "{user_query}"

Here are the relevant services from our database:
{services_context}

Based on these services, provide helpful recommendations for the case manager."""

    # Call Llama via Ollama
    response = ollama.chat(
        model='llama3.2',
        messages=[
            {'role': 'system', 'content': system_prompt},
            {'role': 'user', 'content': user_message}
        ]
    )
    
    return {
        'answer': response['message']['content'],
        'services_found': [m['service_name'] for m in search_results['metadatas'][0]]
    }

print("RAG pipeline ready!")
# Out:
# RAG pipeline ready!

# %% [markdown]
# ## Test the RAG Pipeline

# %%
# Test query 1: Veteran shelter
query = "I have a homeless veteran who needs emergency shelter tonight"

print(f"QUERY: {query}")
print("=" * 70)

result = ask_case_manager_assistant(query)

print("\nSERVICES FOUND:")
for svc in result['services_found']:
    print(f"  - {svc}")

print("\n" + "=" * 70)
print("ASSISTANT RESPONSE:")
print("=" * 70)
print(result['answer'])
# Out:
# QUERY: I have a homeless veteran who needs emergency shelter tonight
# ======================================================================
# /Users/marianne.sawires/.pyenv/versions/3.12.6/lib/python3.12/site-packages/torch/nn/modules/module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# SERVICES FOUND:
#   - National Call Center for Homeless Veterans
#   - Harm Reduction Shelter
#   - Emergency Adult Shelter VVSD
#   - Emergency Adult Shelter VVSD
#   - Homeless Veterans' Reintegration Program
#
# ======================================================================
# ASSISTANT RESPONSE:
# ======================================================================
# **Recommendation:**
#
# Considering the client is a homeless veteran who needs emergency shelter tonight, I recommend contacting **SERVICE 3: Emergency Adult Shelter VVSD** at Father Joe's Villages (phone: (619) 233-8500). This service provides temporary housing for adult men experiencing homelessness, with additional support services such as mental health and substance use support.
#
# While the other services listed may be beneficial, they do not specifically address immediate emergency shelter needs. The National Call Center for Homeless Veterans (SERVICE 1) is primarily a hotline for veterans in need of general assistance, while the Harm Reduction Shelter (SERVICE 2) has specific eligibility criteria that may not be applicable to all homeless veterans.
#
# The other service, Homeless Veterans' Reintegration Program (SERVICE 5), is focused on long-term reintegration and employment services, which may not address the client's immediate needs for shelter.
#
# **Eligibility:**
#
# To ensure the client meets the eligibility requirements:
#
# * The client must be referred through the Coordinated Entry System (CES).
# * Participants must identify as male.
# * There may be income limitations that apply.
#
# **Next Steps:**
#
# 1. Contact Father Joe's Villages to inquire about available rooms and any additional steps required for referral.
# 2. Ensure the client meets the eligibility criteria before proceeding with the referral process.
#
# By reaching out to this service, the case manager can secure emergency shelter for the homeless veteran in need.

# %%
# Test query 2: Family with children
query = "Single mother with 2 kids facing eviction, needs rent assistance and possibly shelter"

print(f"QUERY: {query}")
print("=" * 70)

result = ask_case_manager_assistant(query)

print("\nSERVICES FOUND:")
for svc in result['services_found']:
    print(f"  - {svc}")

print("\n" + "=" * 70)
print("ASSISTANT RESPONSE:")
print("=" * 70)
print(result['answer'])
# Out:
# QUERY: Single mother with 2 kids facing eviction, needs rent assistance and possibly shelter
# ======================================================================
#
# SERVICES FOUND:
#   - Long Term Transitional Housing
#   - Rent and Utility Payment Assistance
#   - City of San Diego Eviction Prevention Program
#   - Emergency Family Shelter
#   - Transitional Housing for Families, St Vincent de Paul Village
#
# ======================================================================
# ASSISTANT RESPONSE:
# ======================================================================
# **Recommendations for the Single Mother with 2 Kids Facing Eviction**
#
# Considering the single mother's situation, I recommend the following services:
#
# 1. **City of San Diego Eviction Prevention Program**: This program offers comprehensive legal assistance and representation to low-income renters at risk of eviction. Given the family's financial struggles, this service could provide crucial support in preventing eviction.
# 2. **Emergency Family Shelter (Interfaith Community Services)**: As a temporary solution for housing instability, this shelter can offer immediate assistance while the mother and children wait for more permanent solutions.
#
# However, considering the family's homelessness situation, I would like to recommend an alternative:
# 3. **Transitional Housing for Families at St Vincent de Paul Village**: This service provides longer-term transitional housing with on-site support services, including employment, education, mental health, and substance abuse support. Given the mother's family is experiencing homelessness, this program could offer a more stable environment while providing necessary support.
#
# **Eligibility Requirements**:
#
# To access these services, please ensure that the single mother meets their respective eligibility requirements:
# - City of San Diego Eviction Prevention Program: Reside in the City of San Diego and have household income at or below 80% of San Diego's Area Median Income.
# - Emergency Family Shelter (Interfaith Community Services): Meet HUD Requirements, reside within North County San Diego, and pass a background check.
# - Transitional Housing for Families at St Vincent de Paul Village: Families experiencing homelessness where the head of household must be either a married adult 18 years or older or have children.
#
# **Next Steps**:
#
# 1. Contact City of San Diego Eviction Prevention Program to discuss eligibility requirements and potential assistance with eviction prevention.
# 2. Reach out to Emergency Family Shelter (Interfaith Community Services) for information on availability, application process, and to schedule an intake.
# 3. Inquire about transitional housing opportunities at St Vincent de Paul Village, including their application process and required documents.
#
# **Additional Notes**:
#
# - It would be beneficial to assess the family's current financial situation to determine if they qualify for rental assistance through Brother Benno Foundation (SERVICE 2: Rent and Utility Payment Assistance).
# - Consider referring the mother to local organizations offering job training, education, and employment resources to help stabilize their income.
#
# Please let me know if you have any further questions or need additional information.

# %%
# Test query 3: Mental health
query = "Young adult age 20 experiencing mental health crisis, needs counseling and possibly housing"

print(f"QUERY: {query}")
print("=" * 70)

result = ask_case_manager_assistant(query)

print("\nSERVICES FOUND:")
for svc in result['services_found']:
    print(f"  - {svc}")

print("\n" + "=" * 70)
print("ASSISTANT RESPONSE:")
print("=" * 70)
print(result['answer'])
# Out:
# QUERY: Young adult age 20 experiencing mental health crisis, needs counseling and possibly housing
# ======================================================================
#
# SERVICES FOUND:
#   - Adult Short-Term Residential Treatment, Jary Barreto Crisis Center
#   - Adult Short-Term Residential Treatment, New Vistas Crisis Center
#   - Adult Short-Term Residential Treatment, Turning Point Crisis Center
#   - Adult Short-Term Residential Treatment, Halcyon Crisis Center
#   - North Inland Mental Health Center
#
# ======================================================================
# ASSISTANT RESPONSE:
# ======================================================================
# **Recommendation for Client's Needs**
#
# Given the client's age (20) and mental health crisis, I recommend Service 1: Adult Short-Term Residential Treatment at Jary Barreto Crisis Center or Service 2: Adult Short-Term Residential Treatment at New Vistas Crisis Center from Community Research Foundation. Both services are specifically designed for adults experiencing a mental health crisis and require inpatient treatment.
#
# **Eligibility Requirements**
#
# To ensure eligibility, please note the following:
#
# * Clients must be 18 years and older.
# * Primary crisis must be a mental health issue (not substance dependence crisis or homelessness).
# * Services may not cover cases with complex needs requiring more specialized care.
#
# **Contact Information and Next Steps**
#
# Please contact Jary Barreto Crisis Center at (619) 232-4357 or New Vistas Crisis Center at (619) 239-4663 to schedule an intake appointment. Inform them about the client's age, mental health crisis, and any relevant medical information.
#
# **Additional Considerations**
#
# Service 5: North Inland Mental Health Center may also be a suitable option if the client lives in North Inland or Coastal Regions of San Diego County. This service provides individual treatment plans with medication assessment to improve symptoms and quality of life.
#
# Please note that each client's needs are unique, and it may take some time to determine the best fit. Encourage the case manager to communicate closely with the client about their options and make informed decisions regarding their care.
#
# **Important Details**
#
# * All services require clients to be 18 years and older.
# * Primary crisis must be a mental health issue for eligibility.
# * Services are designed for acute mental healthcare, not substance dependence crisis or homelessness.
# * Clients should provide relevant medical information and a detailed account of their crisis.

# %% [markdown]
# ## Interactive Query Mode
#
# Run this cell to ask your own questions:

# %%
# Interactive mode - change this query and run the cell
your_query = "elderly person needs help with food and utilities"

print(f"QUERY: {your_query}")
print("=" * 70)

result = ask_case_manager_assistant(your_query)

print("\nSERVICES FOUND:")
for svc in result['services_found']:
    print(f"  - {svc}")

print("\n" + "=" * 70)
print("ASSISTANT RESPONSE:")
print("=" * 70)
print(result['answer'])
# Out:
# QUERY: elderly person needs help with food and utilities
# ======================================================================
#
# SERVICES FOUND:
#   - Senior Nutrition Program
#   - Senior Services
#   - Senior Food Program, Church at Rancho Bernardo
#   - Rent and Utility Payment Assistance
#   - Senior Food Program, Mira Mesa Senior Center
#
# ======================================================================
# ASSISTANT RESPONSE:
# ======================================================================
# **Recommendations**
#
# For an elderly person in need of assistance with food and utilities, I recommend the following services:
#
# 1. **Senior Nutrition Program, City of National City**: This service provides free meals to seniors 60+ years old who live in National City. While it may not directly address utility assistance, it can help alleviate basic needs like food.
# 2. **Brother Benno Foundation's Rent and Utility Payment Assistance**: Given the individual's elderly status, this service could provide emergency assistance with rent and utilities (water, gas, and electric). The case manager should ensure the person meets the eligibility criteria.
# 3. **Senior Food Program, Church at Rancho Bernardo or Senior Food Program, Mira Mesa Senior Center**: Both of these services offer free groceries to low-income seniors 60+ years old who reside in San Diego County. This can help address food insecurity and supplement the individual's basic needs.
#
# **Important Considerations**
#
# Before proceeding with any service, ensure the case manager:
#
# * Verifies the client's eligibility for each recommended service
# * Obtains necessary documentation (e.g., income verification)
# * Explains the service details, including eligibility requirements and application processes
# * Provides information on hours of operation and availability
#
# **Next Steps**
#
# 1. Contact the City of National City to confirm eligibility and schedule a meal pickup at their Senior Nutrition Program.
# 2. Reach out to Brother Benno Foundation's Rent and Utility Payment Assistance to discuss eligibility and gather necessary documentation.
# 3. Contact Jacobs and Cushman San Diego Food Bank (either Church at Rancho Bernardo or Mira Mesa Senior Center) to inquire about the application process for the Senior Food Program.
#
# **Important Details**
#
# * Hours of operation:
# 	+ City of National City: Lunch pickup only, Monday-Friday
# 	+ Brother Benno Foundation: Tuesdays and Thursdays, 9 AM-3 PM
# 	+ Jacobs and Cushman San Diego Food Bank: Check their website for current hours and availability
# * Documents needed:
# 	+ Proof of income (for utility assistance)
# 	+ Identification (e.g., ID card, social security card)
# 	+ Proof of age (for senior programs)

# %% [markdown]
# ## Advanced: Compare Services Side-by-Side

# %%
def compare_services(query, client_profile):
    """
    Ask the LLM to compare services and recommend the best fit.
    """
    search_results = search_services(query, n_results=5)
    services_context = format_services_for_llm(search_results)
    
    prompt = f"""Compare these services for this client:

CLIENT PROFILE:
{client_profile}

AVAILABLE SERVICES:
{services_context}

Please:
1. Create a comparison table of the top 3 most relevant services
2. Recommend which service is the BEST fit and why
3. List any services that are NOT a good fit and why
4. Suggest a step-by-step action plan for the case manager"""

    response = ollama.chat(
        model='llama3.2',
        messages=[{'role': 'user', 'content': prompt}]
    )
    
    return response['message']['content']

# Example comparison
client = """
- 45 year old male
- Veteran (Army, 8 years)
- Currently sleeping in car
- Has part-time job at warehouse
- No mental health or substance issues
- Needs: stable housing, maybe help with deposit
"""

print("CLIENT PROFILE:")
print(client)
print("=" * 70)
print("\nCOMPARISON & RECOMMENDATIONS:")
print("=" * 70)
print(compare_services("veteran housing assistance", client))
# Out:
# CLIENT PROFILE:
#
# - 45 year old male
# - Veteran (Army, 8 years)
# - Currently sleeping in car
# - Has part-time job at warehouse
# - No mental health or substance issues
# - Needs: stable housing, maybe help with deposit
#
# ======================================================================
#
# COMPARISON & RECOMMENDATIONS:
# ======================================================================
# **Comparison Table: Top 3 Services**
#
# | Service | Service Type | Eligibility | Area Served |
# | --- | --- | --- | --- |
# | Veteran's Association of Real Estate Professionals | Housing Education & Counseling | Active duty service members, veterans, reservists, National Guard members, surviving spouses, military families | San Diego County |
# | Adjoin Veterans SSVF Rapid Re-Housing | Homelessness Prevention & Diversion | Limited to individuals where the head of household is a military Veteran with a discharge status other than dishonorable | San Diego County |
# | Coordinated Entry Access Site (CES) | Case Management & Coordination | Veterans who are homeless or at risk of homelessness | North Region of San Diego County |
#
# **Recommendation:**
#
# Based on the client's profile and needs, I recommend Adjoin Veterans SSVF Rapid Re-Housing as the BEST fit service. Here's why:
#
# * The client is currently sleeping in a car and has a part-time job at a warehouse, indicating that they are struggling with housing and need temporary financial assistance.
# * The Adjoin program provides rapid re-housing, which is designed to help individuals quickly find and secure permanent housing.
# * The program also offers case management, housing search assistance, and service referrals, which aligns with the client's need for stable housing and potential support with deposit.
#
# **Services that are NOT a good fit:**
#
# * Veteran's Association of Real Estate Professionals: While this service is focused on education and counseling, it may not provide the immediate financial assistance needed by the client.
# * Coordinated Entry Access Site (CES): This service is primarily designed for homeless veterans in need of case management and coordination. The client's situation doesn't seem to require this level of intensity.
#
# **Step-by-Step Action Plan:**
#
# 1. **Contact Adjoin**: Reach out to Adjoin Veterans SSVF Rapid Re-Housing via phone or email to inquire about the application process and eligibility.
# 2. **Gather required documents**: Collect necessary documents, such as the client's military ID, proof of income, and any other relevant paperwork.
# 3. **Apply for the program**: Submit the application and supporting documents to Adjoin.
# 4. **Schedule an intake appointment**: Arrange a meeting with an Adjoin representative to discuss the client's needs and create a plan.
# 5. **Monitor progress**: Regularly check in with the client to ensure they are making progress with their housing search and any necessary case management support.
#
# Please note that this is just a recommendation, and it's essential to verify eligibility and program details with Adjoin and other relevant organizations before proceeding.

# %% [markdown]
# ## Summary
#
# You now have a working RAG pipeline that:
#
# 1. **Searches** your services database semantically
# 2. **Generates** helpful, contextual responses using Llama
# 3. **Compares** services for specific client profiles
#
# ### Next Steps (Future Enhancements)
#
# | Component | Purpose | Model |
# |-----------|---------|-------|
# | Information Extraction | Structure messy fields (eligibility, hours) | DistilBERT / spaCy |
# | Classification | Auto-tag services, predict eligibility | DistilBERT / BERT |
# | Recommendation Ranking | Score services for specific clients | XGBoost + embeddings |
# | Web Interface | Let case managers use this easily | Streamlit / Gradio |
